# %%
import os

# %%
# %pwd
# Out:
# 'C:\\Users\\abirf\\OneDrive\\Desktop\\Text-Summarizer\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'C:\\Users\\abirf\\OneDrive\\Desktop\\Text-Summarizer'
